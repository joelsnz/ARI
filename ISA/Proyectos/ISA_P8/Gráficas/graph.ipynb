# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset.csv')

df
# Out:
#        OUT  SP     PV
# 0   100.00  30  40.15
# 1     0.00  30  13.04
# 2     0.00  30  13.82
# 3   100.00  30  14.93
# 4   100.00  30  16.17
# 5   100.00  30  17.65
# 6   100.00  30  19.22
# 7   100.00  30  20.96
# 8   100.00  30  22.56
# 9   100.00  30  24.15
# 10   98.10  30  25.60
# 11    8.54  30  27.02
# 12   78.60  30  28.24
# 13   55.71  30  29.44
# 14   29.56  30  30.49
# 15   17.42  30  31.32
# 16    0.00  30  31.87
# 17    0.00  30  32.23
# 18    0.00  30  32.47
# 19    0.00  30  32.53
# 20    0.00  30  32.47
# 21    0.00  30  32.09
# 22    0.00  30  31.84
# 23    0.00  30  31.52
# 24   11.82  30  30.88
# 25   56.59  30  30.58
# 26   98.71  30  30.24
# 27   15.54  30  29.99
# 28   25.75  30  29.63
# 29   37.16  30  29.24
# 30   44.36  30  29.01
# 31   54.21  30  28.95
# 32   54.98  30  29.12
# 33   51.03  30  29.33
# 34   40.90  30  29.75
# 35    3.64  30  30.06
# 36   31.45  30  30.36
# 37   23.89  30  30.37
# 38   27.99  30  30.24
# 39   29.91  30  30.12
# ...

# %%
# representación del PV, SP y salida en el eje Y y el tiempo en el eje X.
plt.figure(figsize=(15, 10))

plt.plot(df.index, df['OUT'], label='Salida')
plt.plot(df.index, df['SP'], label='SP')
plt.plot(df.index, df['PV'], label='PV')

plt.legend()

plt.title('PV, SP y salida con respecto al tiempo')

plt.show()

# %%
# representacion del PV en el eje X y la salida del PID en el eje Y
plt.figure(figsize=(15, 7))

plt.plot(df['PV'][7:-15], df['OUT'][7:-15])

plt.xlabel('PV')
plt.ylabel('Salida')

plt.title('Salida con respecto al PV')

plt.show()
